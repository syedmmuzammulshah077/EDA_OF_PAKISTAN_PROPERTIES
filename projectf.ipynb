# %% [markdown]
# # About Dataset

# %% [markdown]
# The dataset consists of data that was scraped from Zameen.com website. It is Pakistani top leading property buy and sell platform.
#
# Geography: Pakistan
#
#
# Time period: 02-04-2019 – 07-18-2019
#
#
# Unit of analysis: Real states Data Analysis
#
#
# Dataset: The dataset contains detailed information online data available on zameen.com website . It contains property_id,location_id,page_url property_type,price,location,city,province_name,latitude,longitude baths,area,purpose,bedrooms,date_added,agency and agent.
# Variables: The dataset contain property_id,location_id,page_url,property_type,price,location,city,province_name,latitude,longitude baths,area,purpose,bedrooms,date_added,agency agent, Area Type Area Size and Area Category

# %% [markdown]
# ## Step 1: Import Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Reading Dataset

# %%
data = pd.read_csv("zameen-updated.csv")

# %%
data.head(20)
# Out:
#     property_id  location_id  \
# 0        237062         3325
# 1        346905         3236
# 2        386513          764
# 3        656161          340
# 4        841645         3226
# 5        850762         3390
# 6        937975          445
# 7       1258636         3241
# 8       1402466          376
# 9       1418706         3282
# 10      1425602          429
# 11      1586658          429
# 12      1623818         3300
# 13      1665024        11905
# 14      1879795          329
# 15      1879796          329
# 16      1947817         3075
# 17      2230469         9057
# 18      2234957         3116
# 19      2384979          424
#
#                                              page_url property_type  \
# 0   https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat
# 1   https://www.zameen.com/Property/e_11_2_service...          Flat
# 2   https://www.zameen.com/Property/islamabad_g_15...         House
# ...

# %%
data.tail()
# Out:
#         property_id  location_id  \
# 168441     17355248         6754
# 168442     17355249          680
# 168443     17355250         6757
# 168444     17355251         6752
# 168445     17355287        10045
#
#                                                  page_url property_type  \
# 168441  https://www.zameen.com/Property/gulshan_e_maym...         House
# 168442  https://www.zameen.com/Property/gadap_town_gul...         House
# 168443  https://www.zameen.com/Property/gulshan_e_maym...         House
# 168444  https://www.zameen.com/Property/gulshan_e_maym...         House
# 168445  https://www.zameen.com/Property/bahria_town_ka...         House
#
#            price             location     city province_name   latitude  \
# 168441  26500000           Gadap Town  Karachi         Sindh  25.029909
# 168442  12500000           Gadap Town  Karachi         Sindh  25.017951
# 168443  27000000           Gadap Town  Karachi         Sindh  25.015384
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168446 entries, 0 to 168445
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_id    168446 non-null  int64
#  1   location_id    168446 non-null  int64
#  2   page_url       168446 non-null  object
#  3   property_type  168446 non-null  object
#  4   price          168446 non-null  int64
#  5   location       168446 non-null  object
#  6   city           168446 non-null  object
#  7   province_name  168446 non-null  object
#  8   latitude       168446 non-null  float64
#  9   longitude      168446 non-null  float64
#  10  baths          168446 non-null  int64
#  11  area           168446 non-null  object
#  12  purpose        168446 non-null  object
#  13  bedrooms       168446 non-null  int64
#  14  date_added     168446 non-null  object
#  15  agency         124375 non-null  object
#  16  agent          124374 non-null  object
# ...

# %% [markdown]
# ## 2. Summary Statistics:

# %%
data.describe()
# Out:
#         property_id    location_id         price       latitude  \
# count  1.684460e+05  168446.000000  1.684460e+05  168446.000000
# mean   1.559626e+07    4375.936395  1.776576e+07      29.859519
# std    2.251207e+06    3776.561581  3.531003e+07       3.807870
# min    8.657500e+04       1.000000  0.000000e+00      11.052446
# 25%    1.488320e+07    1058.000000  1.750000e+05      24.948536
# 50%    1.665851e+07    3286.000000  8.500000e+06      31.459784
# 75%    1.708662e+07    7220.000000  1.950000e+07      33.560887
# max    1.735772e+07   14220.000000  2.000000e+09      73.184088
#
#            longitude          baths       bedrooms      Area Size
# count  168446.000000  168446.000000  168446.000000  168446.000000
# mean       71.239804       2.874227       3.179422       5.892188
# std         3.133042       2.463400       1.971401       5.778327
# min        25.906027       0.000000       0.000000       0.000000
# ...

# %%
data.nunique()
# Out:
# property_id      168446
# location_id        4198
# page_url         168446
# property_type         7
# price              2077
# location           1509
# city                  5
# province_name         3
# latitude           7838
# longitude          8316
# baths                16
# area                344
# purpose               2
# bedrooms             23
# date_added          124
# agency             5761
# agent             10598
# Area Type             2
# Area Size           247
# Area Category        22
# dtype: int64

# %% [markdown]
# ## Check for Duplication

# %% [markdown]
# ## Missing Values Calculation

# %%
data.isnull().sum()
# Out:
# property_id          0
# location_id          0
# page_url             0
# property_type        0
# price                0
# location             0
# city                 0
# province_name        0
# latitude             0
# longitude            0
# baths                0
# area                 0
# purpose              0
# bedrooms             0
# date_added           0
# agency           44071
# agent            44072
# Area Type            0
# Area Size            0
# Area Category        0
# dtype: int64

# %% [markdown]
# ## The below code helps to calculate the percentage of missing values in each column

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# property_id       0.000000
# location_id       0.000000
# page_url          0.000000
# property_type     0.000000
# price             0.000000
# location          0.000000
# city              0.000000
# province_name     0.000000
# latitude          0.000000
# longitude         0.000000
# baths             0.000000
# area              0.000000
# purpose           0.000000
# bedrooms          0.000000
# date_added        0.000000
# agency           26.163281
# agent            26.163874
# Area Type         0.000000
# Area Size         0.000000
# Area Category     0.000000
# dtype: float64

# %% [markdown]
# ## Step 3: Data Reduction

# %%
# Remove S.No. column from data
data = data.drop(['agency','agent','page_url','Area Category','date_added'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168446 entries, 0 to 168445
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_id    168446 non-null  int64
#  1   location_id    168446 non-null  int64
#  2   property_type  168446 non-null  object
#  3   price          168446 non-null  int64
#  4   location       168446 non-null  object
#  5   city           168446 non-null  object
#  6   province_name  168446 non-null  object
#  7   latitude       168446 non-null  float64
#  8   longitude      168446 non-null  float64
#  9   baths          168446 non-null  int64
#  10  area           168446 non-null  object
#  11  purpose        168446 non-null  object
#  12  bedrooms       168446 non-null  int64
#  13  Area Type      168446 non-null  object
#  14  Area Size      168446 non-null  float64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 19.3+ MB

# %% [markdown]
# ## Step 4: Feature Engineering
# Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data when creating a predictive model using machine learning or statistical modeling. The main goal of Feature engineering is to create meaningful data from raw data.

# %%
data.head()
# Out:
#    property_id  location_id property_type     price     location       city  \
# 0       237062         3325          Flat  10000000         G-10  Islamabad
# 1       346905         3236          Flat   6900000         E-11  Islamabad
# 2       386513          764         House  16500000         G-15  Islamabad
# 3       656161          340         House  43500000    Bani Gala  Islamabad
# 4       841645         3226         House   7000000  DHA Defence  Islamabad
#
#        province_name   latitude  longitude  baths   purpose  bedrooms  \
# 0  Islamabad Capital  33.679890  73.012640      2  For Sale         2
# 1  Islamabad Capital  33.700993  72.971492      3  For Sale         3
# 2  Islamabad Capital  33.631486  72.926559      6  For Sale         5
# 3  Islamabad Capital  33.707573  73.151199      4  For Sale         4
# 4  Islamabad Capital  33.492591  73.301339      3  For Sale         3
#
#   Area Type  Area Size
# 0     Marla        4.0
# 1     Marla        5.6
# ...

# %% [markdown]
# ## Step 5: Creating Features

# %%
data[['property_id','location_id','property_type']]
# Out:
#         property_id  location_id property_type
# 0            237062         3325          Flat
# 1            346905         3236          Flat
# 2            386513          764         House
# 3            656161          340         House
# 4            841645         3226         House
# ...             ...          ...           ...
# 168441     17355248         6754         House
# 168442     17355249          680         House
# 168443     17355250         6757         House
# 168444     17355251         6752         House
# 168445     17355287        10045         House
#
# [168446 rows x 3 columns]

# %% [markdown]
# ## Step 6: Data Cleaning/Wrangling

# %%
print(data.property_type.unique())
print(data.property_type.nunique())
# Out:
# ['Flat' 'House' 'Penthouse' 'Farm House' 'Lower Portion' 'Upper Portion'
#  'Room']
# 7

# %%
searchfor =['Flat' ,'House' ,'Penthouse' ,'Farm House', 'Lower Portion' ,'Upper Portion', 'Room']
data[data.property_type.str.contains('|'.join(searchfor))].head(5)
# Out:
#    property_id  location_id property_type     price     location       city  \
# 0       237062         3325          Flat  10000000         G-10  Islamabad
# 1       346905         3236          Flat   6900000         E-11  Islamabad
# 2       386513          764         House  16500000         G-15  Islamabad
# 3       656161          340         House  43500000    Bani Gala  Islamabad
# 4       841645         3226         House   7000000  DHA Defence  Islamabad
#
#        province_name   latitude  longitude  baths   purpose  bedrooms  \
# 0  Islamabad Capital  33.679890  73.012640      2  For Sale         2
# 1  Islamabad Capital  33.700993  72.971492      3  For Sale         3
# 2  Islamabad Capital  33.631486  72.926559      6  For Sale         5
# 3  Islamabad Capital  33.707573  73.151199      4  For Sale         4
# 4  Islamabad Capital  33.492591  73.301339      3  For Sale         3
#
#   Area Type  Area Size
# 0     Marla        4.0
# 1     Marla        5.6
# ...

# %% [markdown]
# ## Step 7: EDA Exploratory Data Analysis
# Exploratory Data Analysis refers to the crucial process of performing initial investigations on data to discover patterns to check assumptions with the help of summary statistics and graphical representations.
#
# EDA can be leveraged to check for outliers, patterns, and trends in the given
# data.
#
# EDA helps to find meaningful patterns in data.
#
# EDA provides in-depth insights into the data sets to solve our business problems.
#
# EDA gives a clue to impute missing values in the dataset

# %% [markdown]
# ## Step 8: Statistics Summary

# %%
data.describe().T
# Out:
#                 count          mean           std           min           25%  \
# property_id  168446.0  1.559626e+07  2.251207e+06  86575.000000  1.488320e+07
# location_id  168446.0  4.375936e+03  3.776562e+03      1.000000  1.058000e+03
# price        168446.0  1.776576e+07  3.531003e+07      0.000000  1.750000e+05
# latitude     168446.0  2.985952e+01  3.807870e+00     11.052446  2.494854e+01
# longitude    168446.0  7.123980e+01  3.133042e+00     25.906027  6.713036e+01
# baths        168446.0  2.874227e+00  2.463400e+00      0.000000  0.000000e+00
# bedrooms     168446.0  3.179422e+00  1.971401e+00      0.000000  2.000000e+00
# Area Size    168446.0  5.892188e+00  5.778327e+00      0.000000  3.000000e+00
#
#                       50%           75%           max
# property_id  1.665851e+07  1.708662e+07  1.735772e+07
# location_id  3.286000e+03  7.220000e+03  1.422000e+04
# price        8.500000e+06  1.950000e+07  2.000000e+09
# ...

# %%
data.describe(include='all').T
# Out:
#                   count unique          top    freq             mean  \
# property_id    168446.0    NaN          NaN     NaN   15596255.48967
# location_id    168446.0    NaN          NaN     NaN      4375.936395
# property_type    168446      7        House  105468              NaN
# price          168446.0    NaN          NaN     NaN  17765759.832219
# location         168446   1509  DHA Defence   22046              NaN
# city             168446      5      Karachi   60484              NaN
# province_name    168446      3       Punjab   70536              NaN
# latitude       168446.0    NaN          NaN     NaN        29.859519
# longitude      168446.0    NaN          NaN     NaN        71.239804
# baths          168446.0    NaN          NaN     NaN         2.874227
# purpose          168446      2     For Sale  120655              NaN
# bedrooms       168446.0    NaN          NaN     NaN         3.179422
# Area Type        168446      2        Marla  137769              NaN
# ...

# %% [markdown]
# ## Before we do EDA, lets separate Numerical and categorical variables for easy analysis

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['property_type', 'location', 'city', 'province_name', 'purpose',
#        'Area Type'],
#       dtype='object')
# Numerical Variables:
# ['property_id', 'location_id', 'price', 'latitude', 'longitude', 'baths', 'bedrooms', 'Area Size']

# %% [markdown]
# ## Step 9: EDA Univariate Analysis

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# property_id
# Skew : -1.94
# location_id
# Skew : 0.57
# price
# Skew : 9.35
# latitude
# Skew : -0.39
# longitude
# Skew : -0.55
# baths
# Skew : 25.74
# bedrooms
# Skew : 0.71
# Area Size
# Skew : 53.59

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'property_type', data = data, color = 'blue', 
              order = data['property_type'].value_counts().index)
sns.countplot(ax = axes[0, 1], x = 'city', data = data, color = 'blue', 
              order = data['city'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'province_name', data = data, color = 'blue', 
              order = data['province_name'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'purpose', data = data, color = 'blue', 
              order = data['purpose'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'price', data = data, color = 'blue', 
              order = data['price'].value_counts().index);
sns.countplot(ax = axes[2, 1], x =  'Area Size', data = data, color = 'blue', 
              order = data ['Area Size'].value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %%
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))
data.groupby('location')['price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("location Vs price", fontsize=18)
data.groupby('city')['price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("city Vs price", fontsize=18)
data.groupby('province_name')['price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("province_name Vs price", fontsize=18)
data.groupby('Area Type')['price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Area Type Vs price", fontsize=18)
data.groupby('purpose')['price'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][0], fontsize=12)
axarr[2][0].set_title("purpose Vs price", fontsize=18)
data.groupby('Area Size')['price'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][1], fontsize=12)
axarr[2][1].set_title("Area Size Vs price", fontsize=18)
data.groupby('baths')['price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][0], fontsize=12)
axarr[3][0].set_title("baths Vs price", fontsize=18)
data.groupby('bedrooms')['price'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][1], fontsize=12)
axarr[3][1].set_title("bedrooms Vs price", fontsize=18)
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()

# %% [markdown]
# ## Step 10: EDA Multivariate Analysis

# %%
numerical_columns = ['price', 'latitude', 'longitude', 'baths', 'bedrooms','Area Size']

# Calculate the correlation matrix
correlation_matrix = data[numerical_columns].corr()

# %%
# Plotting the heatmap
plt.figure(figsize=(12, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Numerical Variables')
plt.show()
